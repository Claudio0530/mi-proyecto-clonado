# %%
import matplotlib.pyplot as plt

# Datos de prueba
x = [1, 2, 3, 4, 5]
y = [5, 7, 4, 9, 6]

plt.scatter(x, y, color='red')
plt.title('Mi primer gráfico en VS Code')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
